# %% [markdown]
# <center>МИНИСТЕРСТВО НАУКИ И ВЫСШЕГО ОБРАЗОВАНИЯ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЫСШЕГО ОБРАЗОВАНИЯ </center>
# <center>«НОВОСИБИРСКИЙ ГОСУДАРСТВЕННЫЙ ТЕХНИЧЕСКИЙ УНИВЕРСИТЕТ»</center>
# <center>Кафедра Вычислительной техники </center>
# <br>
# <center> <b> <font size="5">  ОТЧЁТ </font>  </b>  </center>
# <center><font size="3">по лабораторной работе №1</font></center>
# <center><font size="3">по дисциплине: «Системы искусственного интеллекта и машинное обучение» </font></center>
# <br>

# %% [markdown]
# - Выполнили: _ _ _ Перцевой Н.Н. _ _ _ Подкорытов А.Н. _ _ _
# - Вариант 207
# - Проверил: _ _ _ Осипенко И.В. _ _ _
# - Новосибирск, 2024

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Цель-работы" data-toc-modified-id="Цель-работы-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Цель работы</a></span></li><li><span><a href="#Ход-работы" data-toc-modified-id="Ход-работы-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Ход работы</a></span></li><li><span><a href="#Содержание-отчета" data-toc-modified-id="Содержание-отчета-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>Содержание отчета</a></span></li></ul></li><li><span><a href="#Работа-с-данными" data-toc-modified-id="Работа-с-данными-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Работа с данными</a></span><ul class="toc-item"><li><span><a href="#Подключение-библиотек" data-toc-modified-id="Подключение-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Подключение библиотек</a></span></li><li><span><a href="#Загрузка-входных-данных" data-toc-modified-id="Загрузка-входных-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка входных данных</a></span></li><li><span><a href="#Осмотр-данных-/-Первичный-анализ" data-toc-modified-id="Осмотр-данных-/-Первичный-анализ-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Осмотр данных / Первичный анализ</a></span><ul class="toc-item"><li><span><a href="#Размер-таблицы" data-toc-modified-id="Размер-таблицы-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Размер таблицы</a></span></li><li><span><a href="#Признаки" data-toc-modified-id="Признаки-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Признаки</a></span></li><li><span><a href="#Названия-признаков" data-toc-modified-id="Названия-признаков-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Названия признаков</a></span></li></ul></li><li><span><a href="#Пропущенные-значения" data-toc-modified-id="Пропущенные-значения-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Пропущенные значения</a></span></li><li><span><a href="#Приведение-признаков-к-числовыми" data-toc-modified-id="Приведение-признаков-к-числовыми-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Приведение признаков к числовыми</a></span></li><li><span><a href="#Формирование-таблицы-с-строго-числовыми-значениями" data-toc-modified-id="Формирование-таблицы-с-строго-числовыми-значениями-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Формирование таблицы с строго числовыми значениями</a></span></li></ul></li><li><span><a href="#Выбор-целевого-значения-и-признаков-для-анализа-данных" data-toc-modified-id="Выбор-целевого-значения-и-признаков-для-анализа-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Выбор целевого значения и признаков для анализа данных</a></span><ul class="toc-item"><li><span><a href="#Корреляция" data-toc-modified-id="Корреляция-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Корреляция</a></span></li></ul></li><li><span><a href="#Просмотр-характеристик-выбранных-признаков" data-toc-modified-id="Просмотр-характеристик-выбранных-признаков-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Просмотр характеристик выбранных признаков</a></span><ul class="toc-item"><li><span><a href="#Поиск-и-обработка-выбросов" data-toc-modified-id="Поиск-и-обработка-выбросов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Поиск и обработка выбросов</a></span></li><li><span><a href="#Сохранение-данных" data-toc-modified-id="Сохранение-данных-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Сохранение данных</a></span></li><li><span><a href="#Формирование-тренировочной-и-проверочной-выборок" data-toc-modified-id="Формирование-тренировочной-и-проверочной-выборок-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Формирование тренировочной и проверочной выборок</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Одномерная-модель-от-признака-'YearBuilt'" data-toc-modified-id="Одномерная-модель-от-признака-'YearBuilt'-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Одномерная модель от признака 'YearBuilt'</a></span></li></ul></li><li><span><a href="#Итоги.-Сравнение-полученных-моделей" data-toc-modified-id="Итоги.-Сравнение-полученных-моделей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Итоги. Сравнение полученных моделей</a></span></li><li><span><a href="#Выводы-по-работе" data-toc-modified-id="Выводы-по-работе-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы по работе</a></span></li></ul></div>

# %% [markdown]
# ## Цель работы

# %% [markdown]
# Получить практические навыки работы по решению задачи первичного анализа «сырых» данных, подготовки массива к обработке, выявления и описания зависимостей в исходных данных с использованием языка программирования.

# %% [markdown]
# ## Ход работы
# Ознакомиться с методическими материалами и примерами выполнения команд.
# Последовательно выполнить следующие шаги применительно к выборке данных, согласно варианту задания:
#
# 1. Работа с данными
#
#   1. Получить \*.csv-файл с исходными данными согласно варианту. С помощью текстового редактора определить наличие заголовка и знак-разделитель столбца
#
#   2. С помощью библиотеки pandas создать таблицу (объект Dataframe) на основе \*.csv-файла с исходными данными
#
#   3. Провести первичный анализ всех данных. Получить размер исходный таблицы
#
#   4. Определить наличие пропусков и выбрать способ их обработки. Получить размер таблицы после обработки пропусков
#
#   5. Определить наличие и привести нужные для работы признаки к числовому типу
#
#   6. Сохранить в виде файла текущее состояние обработанной таблицы (Dataframe)
#
#
# 2. Выбор и обработка признаков
#
#   1. Проверить взаимозависимость всех числовых признаков на основе матрицы корреляции
#
#   2. Выбрать целевую переменную 'y' и независимые признаки 'x1, x2, x3, ...', оказывающие на нее влияние (целевая - 1 шт., признаки>=2 шт.)
#
#   3. Исключить выбросы
#
#   4. Сформировать обучающую и проверочную части выборки
#
#
# 10. Построить линейные регрессионные модели для каждого выбранного признака :
#   - m1: от единственного ЕДИНСТВЕННОЙ переменной (x1) на НЕ стандартизированных  данных
#   - m2: от множества НАБОРА#1 переменных (пример: x1, x2, x3) на НЕ стандартизированных данных
#   - m3: от множества НАБОРА#2 переменных (пример: x5, x6, x7) на НЕ стандартизированных данных
#
# 11. Выполнить анализ полученных моделей:
#
#   1. Получить коэффициенты линейной регрессии y(x) = K*x + B
#
#   2. Получить оценку точности R2(коэфф. детерминации) и RMSE (среднеквадратичное отклонение)
#
#   3. Нанести график прямой y(x) = K*x + B поверх точечной диаграммы (выбранный признак, целевая переменная)
#
#   4. Построить диаграмму рассеяния вычисленных значений Y_pred от проверочных значений Y_test
#
#   5. Построить гистограмму остатков (разностей между Y_pred и Y_test)
#
# 12. \* В качестве доп. задания предлагается расширить множество формируемых моделей.

# %% [markdown]
# # Работа с данными

# %% [markdown]
# ## Подключение библиотек

# %% [markdown]
# Перед началом работы убедитесь, что необходимые для работы пакеты установлены в системе. Для установки отсутствующих используйте команду:
# - pip install numpy pandas sklearn seaborn matplotlib
#
# Назначение библиотек:
# * numpy - обработка многомерных массивов, линейная алгебра, преобразование Фурье, случайные числа
# * pandas - обработка (загрузка, сохранение, анализа) данных
# * seaborn - визуализация данных (на базе matplotlib)
# * sklearn - (классификация, регрессия, кластеризация...)
# * scipy - пакет для выполнения научных и инженерных расчётов.

# %%
# Python 3.8
import pandas as pd
import numpy  as np
np.bool = np.bool_

from sklearn import linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score

# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import cm
import seaborn as sns

# %% [markdown]
# ## Структура входных данных

# %% [markdown]
# Данные "Оценка алмазов" содержат информацию о качествах определенных обработанных алмазов:
# - index counter: индекс алмаза
# - carat: вес,&emsp;[карат]
# - cut - огранка:
#   - Fair - Удовлетворительно;
#   - Good      - Хорошо;
#   - Very Good - Очень хорошо;
#   - Premium   - Премиум;
#   - Ideal     - Идеально.
# - color - цвет оттенка, в диапазоне:
#   - J         - от худшего;
#   - D         - к лучшему.
# - clarity - алмазные включения:
#   - FL        - Без включений и дефектов;
#   - IF        - Без включений, но с дефектами;
#   - VVS1      - Несколько незначительных включений (подгруппа 1);
#   - VVS2      - Несколько незначительных включений (подгруппа 2);
#   - VS1       - Несколько малых включений (подгруппа 1);
#   - VS2       - Несколько малых включений (подгруппа 2);
#   - SI1       - Несколько небольших включений (подгруппа 1);
#   - SI2       - Несколько небольших включений (подгруппа 2);
#   - I1        - Включения, не ухудшающие блеск;
#   - I2        - Включения, ухудшающие блеск;
#   - I3        - Достаточно хрупкий камень, подверженным физическому воздействию.
# - depth: общая глубина,&emsp;[%]
# - table: отношение ширины вершины алмаза к его широчайшему месту,&emsp;&emsp;&nbsp;[%]
# - price: цена,&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&ensp;[доллар]
# - x: длина,&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&ensp;[мм]
# - y: ширина,&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&ensp;&nbsp;[мм]
# - z: глубина,&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&ensp;&nbsp;[мм]

# %% [markdown]
# Для загрузки табличных данных из файла применятся функция .read_csv() с указанием параметров (путь, кодировка, разделитель, обработка колонок с заголовками или датой...)

# %%
df = pd.read_csv('./diamonds_nan.csv', # путь к файлу, (используй автодотолнение)
                   sep=',', # разделитель данных в файле
                   header=0, # номер строки с заголовками, нумерация с нуля
                   # header=None, # если заголовки отсутствуют
                   # na_values =  ['???', ' '], # доп. символы для обозначения отсутствующих значений
)

df[0:2] # отобразить первые строки таблицы df
# Out:
#     ID  carat      cut color clarity  depth  table  price     x     y     z
# 0  1.0   0.23    Ideal     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43
# 1  2.0   0.21  Premium     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31

# %%
print(df[0:2]);
# Out:
#     ID  carat      cut color clarity  depth  table  price     x     y     z
# 0  1.0   0.23    Ideal     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43
# 1  2.0   0.21  Premium     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31

# %% [markdown]
# Переменная __df__ является экземпляром класса __DataFrame__ библиотеки __pandas__.
#
# "DataFrame" - двумерный массив с изменяемым размером  набором полезных функций, каждый столбец которого является экземпляром класса "Series".
#
# | Series | Series | Series | Series |
# |--------|--------|--------|--------|
# | int | string | float | bool |
# | int | string | float | bool |
# | int | string | float | bool |

# %% [markdown]
# Смысловая интерпретация:
#  - каждая строка - объект, алмаз с определеным набором характеристик
#  - каждый столбец - признак, который описывает характеристику объекта (алмаза)

# %% [markdown]
# |   | Признак_0 | Признак_1 | Признак_2 |
# |--------|--------|--------|--------|
# | Объект_0 | string | float | bool |
# | Объект_1 | string | float | bool |
# | Объект_2 | string | float | bool |

# %% [markdown]
# Осмотрим полученную таблицу и убедимся, что данные загружены корректно

# %%
df [0:3] # Квадратные скобки позволяют получить срез исходной таблицы DataFrame[начало:конец]
# Out:
#     ID  carat      cut color clarity  depth  table  price     x     y     z
# 0  1.0   0.23    Ideal     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43
# 1  2.0   0.21  Premium     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31
# 2  3.0   0.23     Good     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31

# %% [markdown]
# ## Осмотр данных / Первичный анализ

# %% [markdown]
# ### Размер таблицы

# %% [markdown]
# Свойство __DataFrame.shape__ возвращает два значения соответствующей таблице - [кол-во строк, кол-во столбов]

# %%
print  (df.shape)
nrow = df.shape[0]
ncol = df.shape[1]
print ("Итого: " + str(nrow) + " записи, " + str(ncol) + " столбец (признак).")
# Out:
# (53940, 11)
# Итого: 53940 записи, 11 столбец (признак).

# %% [markdown]
# ### Признаки

# %% [markdown]
# Метод __describe()__ выводит основные статистически  данных по каждому числовому признаку (типы int64 и float64):
# * count - число непропущенных значений,
# * mean - среднее арифметическое
# * std - стандартное отклонение (среднеквадратическое),
# * min, max - минимальное и максимальное значение
# * 0.25, 0.50, 0.75 квартили.
# * unique - кол-во уникальных значения
# * top - самое часто встречающееся значение
# * freq - кол-во значений 'top'

# %%
df.describe() # описание для числовых значений
# Out:
#                  ID         carat         depth         table         price  \
# count  53918.000000  53918.000000  53918.000000  53909.000000  53917.000000
# mean   26969.156775      0.797964     61.749662     57.457564   3932.976167
# std    15571.226610      0.474026      1.432544      2.234701   3989.497661
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13483.250000      0.400000     61.000000     56.000000    950.000000
# 50%    26969.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40454.750000      1.040000     62.500000     59.000000   5324.000000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53924.000000  53914.000000  53918.000000
# mean       5.731093      5.734673      3.538762
# std        1.121738      1.142057      0.705747
# min        0.000000      0.000000      0.000000
# 25%        4.710000      4.720000      2.910000
# 50%        5.700000      5.710000      3.530000
# 75%        6.540000      6.540000      4.040000
# max       10.740000     58.900000     31.800000

# %% [markdown]
# ### Названия признаков

# %% [markdown]
# Получим список всех столбцов, при помощи свойства __DataFrame.columns__

# %%
df.columns
# Out:
# Index(['ID', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price',
#        'x', 'y', 'z'],
#       dtype='object')

# %% [markdown]
# ## Пропущенные значения

# %% [markdown]
# Осмотрим значения объектов 10-12.

# %%
df[10:13]
# Out:
#       ID  carat      cut color clarity  depth  table  price     x     y     z
# 10  11.0   0.30      NaN     J     SI1   64.0   55.0  339.0  4.25  4.28  2.73
# 11  12.0   0.23    Ideal     J     VS1   62.8   56.0  340.0  3.93  3.90  2.46
# 12  13.0   0.22  Premium     F     SI1   60.4   61.0  342.0  3.88  3.84  2.33

# %% [markdown]
# У объекта DataFrame присутствует функция isna(), которая формирует соответствующую __таблицу-маску__ совпадающую по размеру с исходной, но каждое значение __маски__ - логический индикатор True|False

# %%
df.isna()[10:13]
# Out:
#        ID  carat    cut  color  clarity  depth  table  price      x      y  \
# 10  False  False   True  False    False  False  False  False  False  False
# 11  False  False  False  False    False  False  False  False  False  False
# 12  False  False  False  False    False  False  False  False  False  False
#
#         z
# 10  False
# 11  False
# 12  False

# %% [markdown]
# Над таблицей __таблицей-маской__ допустимо выполнить агрегирующую функцию __.sum()__ , при этом каждое значение TRUE будет приведено к единицы и в результате мы получим количество пропущенных элементов по каждому признаку.

# %%
df.isna().sum()
# Out:
# ID         22
# carat      22
# cut        23
# color      21
# clarity    22
# depth      22
# table      31
# price      23
# x          16
# y          26
# z          22
# dtype: int64

# %% [markdown]
# Для понимания как распределены отсутствующие значения в исходной таблице, попробуем получить графическое изображение __таблицы-маски__
# (Для возможности отображения отсутствующих записей был выбран бОльший масштаб)

# %%
from matplotlib.colors import ListedColormap
def plotTableNA(dataF, addToTilte =""):
    '''  Функция для построения графика отображения отсутствующих значений'''
    if   len(dataF.columns)> 20:   K = 3
    elif len(dataF.columns)== 1:   K = 1
    else:                          K = 1.7 
        
    figSizeH = 15        # размер полотна, высота
    figSizeW =int(len(dataF.columns)/K) # размер полотна, ширина
    fig, ax = plt.subplots( figsize=(figSizeW, figSizeH))

    # отрисовать матрицу значений функцией imshow. Применяется цветовая палитра 
    plt.imshow( dataF.isna(),
                cmap = ListedColormap([ 'yellow', 'red', ]), #cm.get_cmap('jet'),
                aspect='auto',  # ‘auto’ | ‘equal’ | scalar]
                interpolation= 'none',)
    ax.set_xticks(np.arange(len(dataF.columns)))
    ax.set_xticklabels(dataF.columns, rotation=-70,)
    plt.title("Графическое отображение отсутствующих значений (белые). "+ addToTilte)

# Вызов функции с указанием параметров
plotTableNA( df, "Исходный")

# %% [markdown]
# Перед дальнейшими действиями следует обработать пропущенные значения. Варианты обработки:
# - Вар.1. заполнить "особыми" значениями, которые невозможно встретить в выборке (прим.: "#NA")
# - Вар.2. заполнить вычисленными значениями, рассчитанными на основе имеющихся значений признака (средние, мин., макс., и т.д.)
# - Вар.3. исключить строки или столбцы:
#   - Вар.3.1. исключить строки, в которых присутствуют пропущенные значения (Для нас такой способ более приоритетный т.к при отсутствии характеристики алмаза его нет смысла держать в записях)
#   - Вар.3.2. исключить столбцы, в которых присутствуют пропущенные значения

# %%
print("Размер исходного DataFrame", df.shape)
print("Вар.3.1. Размер при исключении по строкам", df.dropna(axis='index', how='any').shape)
print("Вар.3.2. Размер при исключении по столбцам", df.dropna(axis='columns', how='any').shape)
# Out:
# Размер исходного DataFrame (53940, 11)
# Вар.3.1. Размер при исключении по строкам (53690, 11)
# Вар.3.2. Размер при исключении по столбцам (53940, 0)

# %% [markdown]
# Т.к мы имеем не существенные потери записей ,поэтому выбираем режим исключения __"по строкам"__

# %%
# axis='index' - удаление строк
# axis='columns' - удаление столбцов
df = df.dropna(axis='index', how='any')
print("Размер таблицы после исключения пропусков", df.shape)
# Out:
# Размер таблицы после исключения пропусков (53690, 11)

# %% [markdown]
# Необходимо убедится в том, ожидаемый результат совпадает с фактическим.

# %%
df.isna().sum()
# Out:
# ID         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# ## Приведение признаков к числовыми

# %% [markdown]
# На текущем этапе в таблице присутствуют столбцы с категориальными значениями (тип данных object), которые необходимо преобразовать к числовым значениям (тип данных int, float).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53690 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       53690 non-null  float64
#  1   carat    53690 non-null  float64
#  2   cut      53690 non-null  object
#  3   color    53690 non-null  object
#  4   clarity  53690 non-null  object
#  5   depth    53690 non-null  float64
#  6   table    53690 non-null  float64
#  7   price    53690 non-null  float64
#  8   x        53690 non-null  float64
#  9   y        53690 non-null  float64
#  10  z        53690 non-null  float64
# dtypes: float64(8), object(3)
# memory usage: 4.9+ MB

# %% [markdown]
# В нашем случае категориальными признаками являются названия, символьные обозначения и прочее.
#
# Для преобразования к числовым значениям применим только те признаки, количество уникальных значений которых не превышает 8 (строка unique).

# %%
df.describe(include=['object'])  # описание для не числовых значений
# Out:
#           cut  color clarity
# count   53690  53690   53690
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21458  11244   13007

# %% [markdown]
# Метод __pd.get_dummies__ формирует новую таблицу (DataFrame), в которой будут добавлены столбцы по количеству уникальных значений категориального признака.
#
# При этом только в одной группе столбцов соответствующих исходному признаку будет присутствовать единственное значение "1" как признак принадлежности.

# %%
objColNames = ['cut', 'color' , 'clarity'] # названия признаков в исходной таблицы
prefixColNames =  ['cut', 'color' , 'clar']   # сокращенные названия признаков для новой таблицы

df_dummies = pd.get_dummies(
    df[objColNames],       # названия признаков в исходной 
    prefix=prefixColNames  # сокращенные названия в новой
)
df_dummies[:10]
# Out:
#    cut_Fair  cut_Good  cut_Ideal  cut_Premium  cut_Very Good  color_D  \
# 0     False     False       True        False          False    False
# 1     False     False      False         True          False    False
# 2     False      True      False        False          False    False
# 3     False     False      False         True          False    False
# 4     False      True      False        False          False    False
# 5     False     False      False        False           True    False
# 6     False     False      False        False           True    False
# 7     False     False      False        False           True    False
# 8      True     False      False        False          False    False
# 9     False     False      False        False           True    False
#
#    color_E  color_F  color_G  color_H  color_I  color_J  clar_I1  clar_IF  \
# 0     True    False    False    False    False    False    False    False
# 1     True    False    False    False    False    False    False    False
# 2     True    False    False    False    False    False    False    False
# 3    False    False    False    False     True    False    False    False
# 4    False    False    False    False    False     True    False    False
# 5    False    False    False    False    False     True    False    False
# 6    False    False    False    False     True    False    False    False
# 7    False    False    False     True    False    False    False    False
# 8     True    False    False    False    False    False    False    False
# 9    False    False    False     True    False    False    False    False
#
#    clar_SI1  clar_SI2  clar_VS1  clar_VS2  clar_VVS1  clar_VVS2
# 0     False      True     False     False      False      False
# 1      True     False     False     False      False      False
# 2     False     False      True     False      False      False
# 3     False     False     False      True      False      False
# 4     False      True     False     False      False      False
# 5     False     False     False     False      False       True
# 6     False     False     False     False       True      False
# 7      True     False     False     False      False      False
# 8     False     False     False      True      False      False
# 9     False     False      True     False      False      False

# %% [markdown]
# ## Формирование таблицы с строго числовыми значениями

# %% [markdown]
# Полученную таблицу __df_dummies__ объединим с строго числовыми столбцами исходной таблицы. Для этого перечислим названия числовых признаков и используем метод pd.concat()

# %%
# список названий числовых признаков исходной таблицы
digitColName = [
                'ID',
                'carat',
                'depth',
                'table',
                'price',
                'x' ,
                'y' ,
                'z' , ]


# объединить существующую таблицу и новые колонки
df_digPlus  = pd.concat(
                        [
                          df[digitColName],   
                          df_dummies     
                        ], # список объединяемых объектов

                        axis='columns' # способ объединения - по столбцам 
)
df_digPlus[:3]
# Out:
#     ID  carat  depth  table  price     x     y     z  cut_Fair  cut_Good  ...  \
# 0  1.0   0.23   61.5   55.0  326.0  3.95  3.98  2.43     False     False  ...
# 1  2.0   0.21   59.8   61.0  326.0  3.89  3.84  2.31     False     False  ...
# 2  3.0   0.23   56.9   65.0  327.0  4.05  4.07  2.31     False      True  ...
#
#    color_I  color_J  clar_I1  clar_IF  clar_SI1  clar_SI2  clar_VS1  clar_VS2  \
# 0    False    False    False    False     False      True     False     False
# 1    False    False    False    False      True     False     False     False
# 2    False    False    False    False     False     False      True     False
#
#    clar_VVS1  clar_VVS2
# 0      False      False
# 1      False      False
# 2      False      False
#
# [3 rows x 28 columns]

# %% [markdown]
# # Выбор целевого значения и признаков для анализа данных

# %% [markdown]
# <font color='red'> Все последующие действия производятся над таблицей <b>df_digPlus </b></font>

# %% [markdown]
# ## Корреляция

# %% [markdown]
# * __Коэффициент корреляции r-Пирсона__
#
#   Мера линейной взаимосвязи переменных, при нелинейной взаимосвязи непоказателен. Не устойчив к выбросам в выборке. Учитывает числовые значения. Переменные должны иметь нормальное распределение. Изменяется в пределах от -1 до +1.
#
# ![Drag Racing](https://upload.wikimedia.org/wikipedia/commons/thumb/0/02/Correlation_examples.png/400px-Correlation_examples.png)

# %%
corr_df = df_digPlus.corr(method='pearson')
corr_df["price"]
# Out:
# ID              -0.306817
# carat            0.921507
# depth           -0.010683
# table            0.127577
# price            1.000000
# x                0.884391
# y                0.865281
# z                0.861075
# cut_Fair         0.019207
# cut_Good        -0.000211
# cut_Ideal       -0.097226
# cut_Premium      0.095848
# cut_Very Good    0.006261
# color_D         -0.072539
# color_E         -0.101055
# color_F         -0.023808
# color_G          0.008515
# color_H          0.058998
# color_I          0.096896
# color_J          0.081960
# clar_I1         -0.000316
# clar_IF         -0.049405
# clar_SI1         0.008856
# clar_SI2         0.128320
# clar_VS1        -0.009881
# clar_VS2        -0.000832
# clar_VVS1       -0.095522
# clar_VVS2       -0.052289
# Name: price, dtype: float64

# %% [markdown]
# Для того, чтобы визуально оценить величину коэффициентов корреляции построим тепловую карту по значениям взаимозависимости признаков выборки.

# %%
import matplotlib.pyplot as plt
sns.set(style="white")# цвет фона

# построить "маску" для отображения только половины корреляционной матрицы
mask = np.zeros_like(corr_df, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

fig, ax = plt.subplots(figsize=(24,26))
sns.set(font_scale=0.8) # размер шрифта

# Построить тепловую карту
sns.heatmap(
            ##################
            data=corr_df,   ### <<<- объект-матрица корреляции 
            ##################
            vmin=-1, vmax=1, center=0,
            annot=True, 
            cmap = 'RdBu',
            mask=mask,   # применить маску
            square=True, # форма ячейки - квадрат
            linewidths=1.0, # зазор между ячейки
            cbar_kws={"shrink": .7}  # уменьшить размер легенды
           )
plt.title(u'Матрица корреляции признаков');

# %%
# Последовательное применение операции: 
# - получить единственный столбец, 
# - получить абсолютные значения, 
# - отсортировать
corr_df[['price']].abs().sort_values(by="price")
# Out:
#                   price
# cut_Good       0.000211
# clar_I1        0.000316
# clar_VS2       0.000832
# cut_Very Good  0.006261
# color_G        0.008515
# clar_SI1       0.008856
# clar_VS1       0.009881
# depth          0.010683
# cut_Fair       0.019207
# color_F        0.023808
# clar_IF        0.049405
# clar_VVS2      0.052289
# color_H        0.058998
# color_D        0.072539
# color_J        0.081960
# clar_VVS1      0.095522
# cut_Premium    0.095848
# color_I        0.096896
# cut_Ideal      0.097226
# color_E        0.101055
# table          0.127577
# clar_SI2       0.128320
# ID             0.306817
# z              0.861075
# y              0.865281
# x              0.884391
# carat          0.921507
# price          1.000000

# %% [markdown]
# В качестве целевой переменной выберем признак:
# - **'price'** - Стоимость.
#
#
# В качестве независимых переменных выберем признаки с высоким абс. значением коэфф. корреляции, но при этом как можно более не связанные  между собой. Кандидаты:
#   * **'x'** - Длина алмаза
#   * **'carat'**-  Вес алмаза
#   * **'table'** - Общая длина в %
#   * **'cut_Ideal'** - Идеальная огранка

# %% [markdown]
# Составим список исходной и целевой переменных

# %%
features = ['x', 'cut_Ideal', 'table',  'carat', ]
target   = ['price']

# %% [markdown]
# # Просмотр характеристик выбранных признаков

# %% [markdown]
# <font color='red'> Все последующие действия производятся над таблицей <b>df_digPlus </b></font>

# %%
# График признаков попарно
plt.figure(figsize=(7,7))
# %config InlineBackend.figure_format = 'png' # формат изображений PNG, для сокращения времени отрисовки графиков

sns.pairplot(
    df_digPlus[features + target], 
    #hue = 'Type',         # Признак разделения
    kind="scatter",        # Тип даграмм: reg,scatter 
    diag_kind = 'hist',     # Тип диагоральных даграмм: hist, kde
    plot_kws={'alpha':0.3} # прозрачность точек
);

# %% [markdown]
# ## Поиск и обработка выбросов

# %% [markdown]
# <font color='red'> Все последующие действия производятся над таблицей <b>df_digPlus </b></font>

# %% [markdown]
# Судя по виду графиков рассеяния в "пустых областях" присутствуют малое кол-во объектов, т.е. в выборе присутствуют аномально малые или большие значения - "выбросы". Для их обработки проведем следующие операции.

# %%
# Цикл: для каждого элемента в объединенном списке
for feature_name in (features+target):
    
    # Построить полотно для рисования с указанным размером
    plt.figure(figsize=(16,2))
    
    # На созданном полотне отрисовать boxplot
    sns.boxplot( data=df_digPlus[[feature_name]], # данные
                 orient='h' # ориентация графика
               )

# %% [markdown]
# Установим границы значений, для тех объектов таблицы, которые должны остаться

# %%
x_Threshold     = (3.9,8.0)           
table_Threshold = (53, 63)           
price_Threshold  = (450.0, 10500.0)       
carat_Threshold     = (0.3, 1.8)        

# создадим "словарь"/"хэш-таблицу" для удобного обращения, где ключ - это название признака
tressholdDict = { 
    'x'     : x_Threshold,
    'table' : table_Threshold,
    'price'  : price_Threshold,
    'carat'     : carat_Threshold,
}

print (tressholdDict)
# Out:
# {'x': (3.9, 8.0), 'table': (53, 63), 'price': (450.0, 10500.0), 'carat': (0.3, 1.8)}

# %% [markdown]
# Проверим, какая часть данных выходит за пределы границ значений

# %%
# Цикл: для каждого элемента в словаре/хэш-таблице пройтись по ключам - названиям признаков
for feature_name  in tressholdDict:
    threesMin =  tressholdDict[feature_name][0] # извлечь нижнее пороговое
    tresshMax =  tressholdDict[feature_name][1] # извлечь верхнее пороговое

    # Получить кол-во эл. вне пороговых значений. Прием - фильтрация
    over_count = len(  df_digPlus[ 
                            ~(df_digPlus[feature_name] >= threesMin ) & (df_digPlus[feature_name] <= tresshMax) # фильтр по двум границам. ~ инверсия логических значений
                          ] 
                    )
    
    dcount = df_digPlus[feature_name].count() # кол-во эл. общее
    
    print ('''{}. Принимаем пороговые значение равными {}.
  Кол-во эл. вне пороговых - {} из {} значение(ий) ({:.1%})\n'''.format( 
        feature_name, 
        tressholdDict[feature_name],
        over_count,
        dcount,
        over_count/ dcount,
    ))
# Out:
# x. Принимаем пороговые значение равными (3.9, 8.0).
#   Кол-во эл. вне пороговых - 65 из 53690 значение(ий) (0.1%)
#
# table. Принимаем пороговые значение равными (53, 63).
#   Кол-во эл. вне пороговых - 76 из 53690 значение(ий) (0.1%)
#
# price. Принимаем пороговые значение равными (450.0, 10500.0).
#   Кол-во эл. вне пороговых - 853 из 53690 значение(ий) (1.6%)
#
# carat. Принимаем пороговые значение равными (0.3, 1.8).
#   Кол-во эл. вне пороговых - 1590 из 53690 значение(ий) (3.0%)

# %% [markdown]
# Отфильтруем значения которые находятся вне пороговых.

# %%
# Во избежание путаницы создадим для последующих операций копию исходного объетка
df_digPlusFiltred = df_digPlus.copy()

for feature_name  in tressholdDict:
    threesMin =  tressholdDict[feature_name][0]
    tresshMax =  tressholdDict[feature_name][1]
    
    
    # фильтр по двум границам. Оператор "~" -инверсия логических значений
    df_digPlusFiltred = df_digPlusFiltred[ 
        (df_digPlusFiltred[feature_name] >= threesMin ) & (df_digPlusFiltred[feature_name] <= tresshMax) 
        ]
    print("Обработан ", feature_name )
    
    
print ("Отброшено {} строк. Осталось {} строк.".format(
    len(df_digPlus)  - len(df_digPlusFiltred),
    len(df_digPlusFiltred))

)
df_digPlusFiltred[:10]
# Out:
# Обработан  x
# Обработан  table
# Обработан  price
# Обработан  carat
# Отброшено 7577 строк. Осталось 46113 строк.
#       ID  carat  depth  table  price     x     y     z  cut_Fair  cut_Good  \
# 60  61.0   0.35   60.9   57.0  552.0  4.54  4.59  2.78     False     False
# 61  62.0   0.30   62.6   59.0  552.0  4.23  4.27  2.66     False     False
# 62  63.0   0.30   62.5   57.0  552.0  4.29  4.32  2.69     False     False
# 63  64.0   0.30   62.1   56.0  552.0  4.30  4.33  2.68     False     False
# 64  65.0   0.42   61.5   59.0  552.0  4.78  4.84  2.96     False     False
# 66  67.0   0.32   62.0   55.3  553.0  4.39  4.42  2.73     False     False
# 67  68.0   0.31   63.3   57.0  553.0  4.33  4.30  2.73     False     False
# 68  69.0   0.31   61.8   58.0  553.0  4.35  4.32  2.68     False     False
# 71  72.0   0.30   63.1   56.0  554.0  4.29  4.27  2.70     False     False
# 72  73.0   0.30   62.9   59.0  554.0  4.28  4.24  2.68     False     False
#
#     ...  color_I  color_J  clar_I1  clar_IF  clar_SI1  clar_SI2  clar_VS1  \
# 60  ...     True    False    False    False     False     False      True
# 61  ...    False    False    False    False      True     False     False
# 62  ...    False    False    False    False      True     False     False
# 63  ...    False    False    False    False      True     False     False
# 64  ...     True    False    False    False     False      True     False
# 66  ...     True    False    False    False     False     False     False
# 67  ...    False    False    False    False      True     False     False
# 68  ...    False    False    False    False      True     False     False
# 71  ...    False    False    False    False      True     False     False
# 72  ...    False    False    False    False      True     False     False
#
#     clar_VS2  clar_VVS1  clar_VVS2
# 60     False      False      False
# 61     False      False      False
# 62     False      False      False
# 63     False      False      False
# 64     False      False      False
# 66     False       True      False
# 67     False      False      False
# 68     False      False      False
# 71     False      False      False
# 72     False      False      False
#
# [10 rows x 28 columns]

# %%
# Строим гистограммы по каждому признаку: 
# data[features].hist() #Упрощенный вывод графиков

features_hist = ['x', 'table',  'carat', ]
target_hist   = ['price']

fig = plt.figure(figsize=(28, 8))
plot_number = 0
#plt.subplot(1, len(features+target))
for feature_name in (features_hist+target_hist):
    plot_number = plot_number + 1
   # plt.subplot(1, len(features+target), plot_number)
    tmp = fig.add_subplot(1 , len(features_hist+target_hist) , plot_number)
    
    tmp.hist(df_digPlusFiltred[feature_name]) # Построение гистрограммы
    tmp.set(title = feature_name)
    tmp.set_xlabel('Значение')
    tmp.set_ylabel('Частота')
    print (feature_name, df_digPlusFiltred[feature_name].min(), df_digPlusFiltred[feature_name].max())

plt.show()
# Out:
# x 4.14 7.97
# table 53.0 63.0
# carat 0.3 1.8
# price 450.0 10499.0

# %% [markdown]
# ## Сохранение данных

# %% [markdown]
# <font color='red'> Все последующие действия производятся над таблицей <b>df_digPlusFiltred </b></font>

# %%
df_digPlusFiltred.to_csv('./diamonds_nan_PREPARED.csv', # путь для сохранения
            index=False, # запрет сохранения "индексов" (тек. номеров строк)
           )

# %% [markdown]
# Некоторые методы машинного обучения
# сильно чувствительны к шкалированию данных.
#
# Перед запуском алгоритмов чаще всего выполняются процедуры:
#
# - либо __нормализации__  -  приведения значений к диапазону от 0.0 до 1.0 Пример:
#
#       |--------------|+++++++++|----|
#       |--------------|++++++++++++++|
#       0             1900     1970  2000
#
#       Обрабатываемое: 1970
#       Макс. значение: 1900
#       Мин. значение:  2000
#
#       Процедура нормирования:
#       x_norm = ( x - X.min() ) / ( X.max() -  X.min() )
#       x_norm = ( 1970 - 1900 ) / (2000 - 1900)
#       x_norm = 70 / 100
#       x_norm = 0.70
#
#       Восстановление:
#       x = ( x_norm * ( X.max() -  X.min() ) +  X.min()
#       x = ( 0.70 * (2000 - 1900) + 1900
#       x = ( 0.70 * 100) + 1900
#       x = 70 + 1900
#       x = 1970
#
# - либо __стандартизации__ - предобработки данных, после которой каждый признак имеет среднее (mean) = 0 и дисперсию (variance) = 1. Стандартизовать - вычесть среднее и поделить на стандартное отклонение. Критично для линейных моделей.
#       X_stantartised = (X - X.mean()) / X.std()
#
# "Одно из наиболее важных допущений при работе с линейными моделями, параметры которых оцениваются методом наименьших квадратов, состоит в том, что остатки модели независимы (т.е. не коррелируют) и имеют нормальное распределение со средним значением 0 и некоторым фиксированным стандартным отклонением"

# %% [markdown]
# ## Формирование тренировочной и проверочной выборок

# %% [markdown]
# <font color='red'> Все последующие действия производятся над таблицей <b>df_digPlusFiltred </b></font>

# %% [markdown]
# Для обучения и проверки качества модели применяют прием заключающийся в разделении исходной выборки на части:
# * Обучающую (Train) - данные, на которых модель формирует коэффициенты
# * Проверочную (Test) - данные, которые предъявляют обученой модели для получения и сравнения вычисленных(Predicted) значений.
#
# Для разделения воспользуемся функцией __train_test_split__ из пакета __sklearn__

# %% [markdown]
# ![train-test-split.png](data:image/png;base64,...)

# %%
valid_size = 0.3 # доля тестовой части в выборке
rand_seed = 8 # начальное состояние генератора случ. чисел

x_train, x_test, y_train, y_test =  train_test_split(
    df_digPlusFiltred[features],    # исходные данные X
    df_digPlusFiltred[target],      # исходные данные y
    
    test_size = valid_size, # доля тестовой части в выборке
    random_state=rand_seed, # начальное состояние генератора случ. чисел
    shuffle=True            # перемешивание
)

# %%
print ("Кол-во элементов: \n  x_train: {}, y_train {} \n  x_test:  {}, y_test  {} \n  total x: {}, total y {} ".format  (
    len(x_train), len(y_train),
    len(x_test),  len(x_test), 
    len(x_train)+len(x_test), len(y_train)+len(x_test),
))
# Out:
# Кол-во элементов:
#   x_train: 32279, y_train 32279
#   x_test:  13834, y_test  13834
#   total x: 46113, total y 46113

# %% [markdown]
# Проверим содержимое обучающей и проверочной

# %%
x_test[:3]
# Out:
#           x  cut_Ideal  table  carat
# 15874  6.81      False   61.0   1.20
# 42987  5.67      False   63.0   0.60
# 35520  4.86      False   57.0   0.43

# %%
y_test[:3]
# Out:
#         price
# 15874  6350.0
# 42987  1367.0
# 35520   905.0

# %% [markdown]
# # Построение модели

# %% [markdown]
# <font color='red'> Все последующие действия производятся над таблицами <b>x_train, x_test, y_train, y_test </b></font>

# %% [markdown]
# Для получения линейной регрессионной модели создадим экземпляр класс
# __sklearn.linear_model.LinearRegression()__

# %%
lr = linear_model.LinearRegression()

# %% [markdown]
# Полученная модель требует процедуры обучения - подбора значений коэфф. для минимизации отличий между вычисленными значениями и предоставленными целевыми (обучающими y). У большинства моделей доступен метод __.fit( x_train,y_train)__

# %%
# Вычислить коэфф. на тренировочном наборе, т.е. обучить модель
lin_model_table = lr.fit( #ТРЕНИРОВОЧНАЯ МОДЕЛЬ
    x_train[['table']], 
    y_train[['price']]
)

# Получить вычисленные(predicted) зн. на проверочном наборе
# y_pred = fittedModel.predict(x_test)
y_pred_Pricetable  = lin_model_table.predict(x_test[['table']])

# %% [markdown]
# Для наглядности построим график рассеяния (он же график разброса, точечный, scatter)

# %%
# Создать полотно для рисования с указаными размерами
plt.figure(figsize=(15,5))

# Нанести график рассеяния - plt.scatter
plt.scatter(x_train[['table']],  y_train[['price']], alpha=0.3, label='Тренировочный') # тренировочный
plt.scatter(x_test[['table']],   y_test[['price']],  alpha=0.3, label='Проверочный')   # проверочный

# Нанести график - линии через точки - plt.plot
label_str = "y_pred (x) = x * {:.0f} + {:.0f}".format(lin_model_table.coef_[0][0], lin_model_table.intercept_[0])
plt.plot( x_test[['table']], y_pred_Pricetable,
         lw=2, color='red', label=label_str)


plt.legend(loc="best")  # положение легенды
plt.xlabel('table') # подпись осей
plt.ylabel(target[0])   # подпись осей
plt.title(u'График разброса'); # Заголовок

# %% [markdown]
# Т.к. модель является линейной имеются некоторые расхождения между реальными и вычисленными значениями - "ошибки". Для оценки точности построим гистограмму распределения ошибок

# %%
plt.figure(figsize=(6,4))

# Гистограмма и Плотность распределения - sns.distplot
# data = y_true - y_pred
#sns.distplot(y_test[['Price']]- y_pred_PriceYearBuilt)
sns.histplot(y_test[['price']]- y_pred_Pricetable, 
             color="red", 
             kde=True, # оценка плотности в виде кривой
             stat="density",# density: общая площадь равна 1
            )

# Осевая линия
plt.plot(
    [0, 0],
    [0, 10 * pow(10,-5)], '--', lw=2, c='r')

plt.ylabel(u'Плотность')
plt.xlabel(u'Значение ошибки')
plt.title(u'Плотность распределения и гистограмма ошибок');
plt.show()

# %% [markdown]
# Построим еще пару графиков для визуальной оценки качества модели

# %%
plt.figure(figsize=(12,6))

# создать первое полотно 121: 1-строк, 2-столбцов, 1-индекс в сетке
plt.subplot(121)
plt.scatter(y_test[['price']], y_pred_Pricetable,  alpha=0.1)
plt.scatter(y_test[['price']], y_test[['price']],  alpha=0.1)
plt.title('Диаграмма рассеяния вычисленных значений');
plt.xlabel('Проверочное Y')
plt.ylabel('Вычисленное Y')

# создать первое полотно 121: 1-строк, 2-столбцов, 2-индекс в сетке
plt.subplot(122)
plt.scatter(y_test[['price']], (y_test[['price']] - y_pred_Pricetable)**2,  alpha=0.1)

plt.title('Диаграмма рассеяния ошибок')
plt.xlabel('Проверочное Y')
plt.ylabel('Абсолютная ошибка')
# Out:
# Text(0, 0.5, 'Абсолютная ошибка')

# %% [markdown]
# С помощью функций __sklearn.metrics.*__ сравним реальные и вычисленные значения и получим важные оценки качества модели

# %%
y_true = [4, 2, 3.5, 1, 3, ] # проверочные
y_pred = [5, 2, 1.5, 1, 3, ] # вычисленные
rmse_LinRegr_table = np.sqrt( metrics.mean_squared_error(y_true, y_pred))
print ("RMSE - кв. корень из среднеквадратичной ошибки: {:>7,.3f}".format( rmse_LinRegr_table ))
# Out:
# RMSE - кв. корень из среднеквадратичной ошибки:   1.000

# %%
print ("Линейная одномерная регрессия. Признак 'table'.")
print ("y_pred_Pricetable (x) = x * {} + {}\n".format(
    lin_model_table.coef_, lin_model_table.intercept_))

r2_LinRegr_table   = metrics.r2_score                   (y_test[['price']], y_pred_Pricetable)
mae_LinRegr_table  = metrics.mean_absolute_error        (y_test[['price']], y_pred_Pricetable)
rmse_LinRegr_table = np.sqrt( metrics.mean_squared_error(y_test[['price']], y_pred_Pricetable))


print ("R2 - коэфф. детерминации:        {:>7,.3f}".format               ( r2_LinRegr_table ))
print ("MAE - средняя абсолютная ошибка: {:>7,.3f}".format               ( mae_LinRegr_table ))
print ("RMSE - кв. корень из среднеквадратичной ошибки: {:>7,.3f}".format( rmse_LinRegr_table ))
# Out:
# Линейная одномерная регрессия. Признак 'table'.
# y_pred_Pricetable (x) = x * [[174.08584592]] + [-6917.27805473]
#
# R2 - коэфф. детерминации:          0.020
# MAE - средняя абсолютная ошибка: 2,008.994
# RMSE - кв. корень из среднеквадратичной ошибки: 2,453.291

# %% [markdown]
# ## Многомерная модель от  НАБОРА#1 переменных (пример: x1, x2, x3, ...)

# %%
lr_x1x2x3 = linear_model.LinearRegression()

# Вычислить коэфф. на тренировочном наборе, т.е. обучить модель
lin_model_x1x2x3 = lr_x1x2x3.fit(
x_train[['x', 'table', 'carat']], 
y_train[['price']]
)

# Получить вычисленные(predicted) зн. на проверочном наборе
#y_pred = fittedModel.predict(x_test)
y_pred_x1x2x3  = lin_model_x1x2x3.predict(x_test[['x', 'table', 'carat']])

plt.figure(figsize=(10,6))

# Гистограмма и Плотность распределения - sns.distplot
# data = y_true - y_pred
#sns.distplot(y_test[['Price']]- y_pred_PriceYearBuilt)
sns.histplot(y_test[['price']]- y_pred_x1x2x3, 
             color="red", 
             kde=True, # оценка плотности в виде кривой
             stat="density",# density: общая площадь равна 1
            )

# Осевая линия
plt.plot(
    [0, 0],
    [0, 8*10 * pow(10,-5)], '--', lw=2, c='r')

plt.ylabel(u'Плотность')
plt.xlabel(u'Значение ошибки')
plt.title(u'Плотность распределения и гистограмма ошибок');
plt.show()

# %%
plt.figure(figsize=(12,6))

# создать первое полотно 121: 1-строк, 2-столбцов, 1-индекс в сетке
plt.subplot(121)
plt.scatter(y_test[['price']], y_pred_x1x2x3,  alpha=0.1)
plt.scatter(y_test[['price']], y_test[['price']],  alpha=0.1)
plt.title('Диаграмма рассеяния вычисленных значений');
plt.xlabel('Проверочное Y')
plt.ylabel('Вычисленное Y')

# создать первое полотно 121: 1-строк, 2-столбцов, 2-индекс в сетке
plt.subplot(122)
plt.scatter(y_test[['price']], (y_test[['price']] - y_pred_x1x2x3)**2,  alpha=0.1)

plt.title('Диаграмма рассеяния ошибок')
plt.xlabel('Проверочное Y')
plt.ylabel('Абсолютная ошибка')
# Out:
# Text(0, 0.5, 'Абсолютная ошибка')

# %%
print ("Линейная одномерная регрессия. Признаки 'x', 'table', 'carat'.")
print ("y_pred_x1x2x3 (x) = x * {} + {}\n".format(
    lin_model_x1x2x3.coef_, lin_model_x1x2x3.intercept_))

mae_LinRegr_x1x2x3  = metrics.mean_absolute_error        (y_test[['price']], y_pred_x1x2x3)
rmse_LinRegr_x1x2x3 = np.sqrt( metrics.mean_squared_error(y_test[['price']], y_pred_x1x2x3))
r2_LinRegr_x1x2x3   = metrics.r2_score                   (y_test[['price']], y_pred_x1x2x3)

print ("MAE - средняя абсолютная ошибка: {}".format               ( mae_LinRegr_x1x2x3 ))
print ("RMSE - кв. корень из среднеквадратичной ошибки: {}".format( rmse_LinRegr_x1x2x3 ))
print ("R2 - коэфф. детерминации:        {}".format               ( r2_LinRegr_x1x2x3 ))
# Out:
# Линейная одномерная регрессия. Признаки 'x', 'table', 'carat'.
# y_pred_x1x2x3 (x) = x * [[-503.8698714   -46.02979988 7879.98264047]] + [2856.94162611]
#
# MAE - средняя абсолютная ошибка: 615.9766490760651
# RMSE - кв. корень из среднеквадратичной ошибки: 956.4123370764848
# R2 - коэфф. детерминации:        0.8510749246526659

# %% [markdown]
# ## Многомерная модель от  НАБОРА#2 переменных (пример: x5, x6, x7, ...)

# %%
lr_x4x5x6 = linear_model.LinearRegression()

# Вычислить коэфф. на тренировочном наборе, т.е. обучить модель
lin_model_x4x5x6 = lr_x4x5x6.fit(
x_train[['x', 'cut_Ideal', 'carat']], 
y_train[['price']]
)

# Получить вычисленные(predicted) зн. на проверочном наборе
#y_pred = fittedModel.predict(x_test)
y_pred_x4x5x6  = lin_model_x4x5x6.predict(x_test[['x', 'cut_Ideal', 'carat']])

plt.figure(figsize=(10,6))

# Гистограмма и Плотность распределения - sns.distplot
# data = y_true - y_pred
#sns.distplot(y_test[['Price']]- y_pred_PriceYearBuilt)
sns.histplot(y_test[['price']]- y_pred_x4x5x6, 
             color="red", 
             kde=True, # оценка плотности в виде кривой
             stat="density",# density: общая площадь равна 1
            )

# Осевая линия
plt.plot(
    [0, 0],
    [0, 8*10 * pow(10,-5)], '--', lw=2, c='r')

plt.ylabel(u'Плотность')
plt.xlabel(u'Значение ошибки')
plt.title(u'Плотность распределения и гистограмма ошибок');
plt.show()

# %%
plt.figure(figsize=(12,6))

# создать первое полотно 121: 1-строк, 2-столбцов, 1-индекс в сетке
plt.subplot(121)
plt.scatter(y_test[['price']], y_pred_x4x5x6,  alpha=0.1)
plt.scatter(y_test[['price']], y_test[['price']],  alpha=0.1)
plt.title('Диаграмма рассеяния вычисленных значений');
plt.xlabel('Проверочное Y')
plt.ylabel('Вычисленное Y')

# создать первое полотно 121: 1-строк, 2-столбцов, 2-индекс в сетке
plt.subplot(122)
plt.scatter(y_test[['price']], (y_test[['price']] - y_pred_x4x5x6)**2,  alpha=0.1)

plt.title('Диаграмма рассеяния ошибок')
plt.xlabel('Проверочное Y')
plt.ylabel('Абсолютная ошибка')
# Out:
# Text(0, 0.5, 'Абсолютная ошибка')

# %%
print ("Линейная одномерная регрессия. Признаки 'x', 'cut_Ideal', 'carat'.")
print ("y_pred_x4x5x6 (x) = x * {} + {}\n".format(
    lin_model_x4x5x6.coef_, lin_model_x4x5x6.intercept_))

mae_LinRegr_x4x5x6  = metrics.mean_absolute_error        (y_test[['price']], y_pred_x4x5x6)
rmse_LinRegr_x4x5x6 = np.sqrt( metrics.mean_squared_error(y_test[['price']], y_pred_x4x5x6))
r2_LinRegr_x4x5x6   = metrics.r2_score                   (y_test[['price']], y_pred_x4x5x6)

print ("MAE - средняя абсолютная ошибка: {}".format               ( mae_LinRegr_x4x5x6 ))
print ("RMSE - кв. корень из среднеквадратичной ошибки: {}".format( rmse_LinRegr_x4x5x6 ))
print ("R2 - коэфф. детерминации:        {}".format               ( r2_LinRegr_x4x5x6 ))
# Out:
# Линейная одномерная регрессия. Признаки 'x', 'cut_Ideal', 'carat'.
# y_pred_x4x5x6 (x) = x * [[-555.89414662  317.7220626  8046.9383719 ]] + [257.01930942]
#
# MAE - средняя абсолютная ошибка: 615.5251942018517
# RMSE - кв. корень из среднеквадратичной ошибки: 953.5200787093567
# R2 - коэфф. детерминации:        0.8519742825967973

# %% [markdown]
# # Итоги. Сравнение полученных моделей

# %%
import pandas as pd

ddf = pd.DataFrame (
    {
        "Признак": ["table", "x1, x2, x3", "x4, x5, x6"],
        "K":       [174.08,     "-503.8698714   -46.02979988 7879.98264047",     "-555.89414662  317.7220626  8046.9383719"], 
        "B":       [-6917.27,     2856.94162611,     257.01],
        "MAE":     [2008.9,     615.9,     615.5],
        "RMSE":    [2453.3,     956.4,     953.5],
        "R2":      [0.02,      0.85,    0.85],
    }
 )
ddf
# Out:
#       Признак                                          K            B     MAE  \
# 0       table                                     174.08 -6917.270000  2008.9
# 1  x1, x2, x3  -503.8698714   -46.02979988 7879.98264047  2856.941626   615.9
# 2  x4, x5, x6   -555.89414662  317.7220626  8046.9383719   257.010000   615.5
#
#      RMSE    R2
# 0  2453.3  0.02
# 1   956.4  0.85
# 2   953.5  0.85

# %% [markdown]
# # Выводы по работе

# %% [markdown]
# В данной лабораторной работе мы получили практические навыки работы по решению задачи первичного анализа «сырых» данных, подготовки массива к обработке, выявления и описания зависимостей в исходных данных с использованием языка программирования Python. В итоге мы получили три модели основанные на разных данных, исходя из которых можно сделать вывод, что для продажи алмазов лучшим вариантом будет ориентироваться на их качество огранки, вес и размер.

# %%
y_true = [4, 2, -2, 3] # проверочные
y_pred = [2, 4, 0, 1] # вычисленные
rmse_LinRegr_table = np.sqrt( metrics.mean_squared_error(y_true, y_pred))
print ("RMSE - кв. корень из среднеквадратичной ошибки: {:>7,.3f}".format( rmse_LinRegr_table ))
# Out:
# RMSE - кв. корень из среднеквадратичной ошибки:   2.000

# %%
df_digPlusFiltred[:10]
# Out:
#       ID  carat  depth  table  price     x     y     z  cut_Fair  cut_Good  \
# 60  61.0   0.35   60.9   57.0  552.0  4.54  4.59  2.78     False     False
# 61  62.0   0.30   62.6   59.0  552.0  4.23  4.27  2.66     False     False
# 62  63.0   0.30   62.5   57.0  552.0  4.29  4.32  2.69     False     False
# 63  64.0   0.30   62.1   56.0  552.0  4.30  4.33  2.68     False     False
# 64  65.0   0.42   61.5   59.0  552.0  4.78  4.84  2.96     False     False
# 66  67.0   0.32   62.0   55.3  553.0  4.39  4.42  2.73     False     False
# 67  68.0   0.31   63.3   57.0  553.0  4.33  4.30  2.73     False     False
# 68  69.0   0.31   61.8   58.0  553.0  4.35  4.32  2.68     False     False
# 71  72.0   0.30   63.1   56.0  554.0  4.29  4.27  2.70     False     False
# 72  73.0   0.30   62.9   59.0  554.0  4.28  4.24  2.68     False     False
#
#     ...  color_I  color_J  clar_I1  clar_IF  clar_SI1  clar_SI2  clar_VS1  \
# 60  ...     True    False    False    False     False     False      True
# 61  ...    False    False    False    False      True     False     False
# 62  ...    False    False    False    False      True     False     False
# 63  ...    False    False    False    False      True     False     False
# 64  ...     True    False    False    False     False      True     False
# 66  ...     True    False    False    False     False     False     False
# 67  ...    False    False    False    False      True     False     False
# 68  ...    False    False    False    False      True     False     False
# 71  ...    False    False    False    False      True     False     False
# 72  ...    False    False    False    False      True     False     False
#
#     clar_VS2  clar_VVS1  clar_VVS2
# 60     False      False      False
# 61     False      False      False
# 62     False      False      False
# 63     False      False      False
# 64     False      False      False
# 66     False       True      False
# 67     False      False      False
# 68     False      False      False
# 71     False      False      False
# 72     False      False      False
#
# [10 rows x 28 columns]
